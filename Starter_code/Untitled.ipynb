# %%
combined_df = pd.concat([tsla_df, sp500_df], axis="columns", join="inner")
combined_df.head()

whale_navs_csv["Shift_1"] = whale_navs_csv.shift(1)
whale_navs_csv.head()



tsla_df["pct_change"] = tsla_df["close"].pct_change()----3 part

part 4
ax.legend(['whale_navs Cumulative Return',
          ])

ax = aapl_cumulative_returns.plot(figsize=(20,10), title="Cumulative Returns of Apple, Amazon and Google 2017-2019")
amzn_cumulative_returns.plot(ax=ax)
goog_cumulative_returns.plot(ax=ax)

cumulative_returns = (1 + daily_returns).cumprod() - 1
cumulative_returns

whale_navs_daily_returns.dropna(column=['S&P500'], inplace=True)


apl_df.rolling(window=30).mean().plot(ax=ax)

ax.legend(["aapl", "aapl 30 Day Mean"])


combined_df.plot(kind='scatter', x='MSFT', y='SP500')

whale_navs_dataframe= whale_navs_d['S&P 500'].pct_change().dropna(whale_navs_dataframe['S&P 500'])


verage_annual_return_portfolio_a_b = daily_returns_a_b.mean() * year_trading_days
annual_std_dev_portfolios_a_b = daily_returns_a_b.std() * np.sqrt(year_trading_days)
annual_std_dev_portfolios_a_b

sharpe_ratios_a_b.sort_values()




nflx_std_100 = nflx_df.rolling(window=60).var()

market_rolling_30_variance = daily_returns['S&P 500'].rolling(window=30).var()

print(f"S&P500 var: {market_variance: .8f}")

market_rolling_30_variance.plot(
    figsize=(10, 7),
    title='Rolling 30-Day Variance of S&P 500 Returns'
)


snp_rolling_30_variance = tech_daily_returns['S&P 500'].rolling(window=30).var()

fb_rolling_30_covariance = tech_daily_returns['FB'].rolling(window=30).cov(tech_daily_returns['S&P 500'])


fb_rolling_30_beta = fb_rolling_30_covariance / snp_rolling_30_variance


twtr_rolling_30_beta.plot(figsize=(10,7), title="TWTR - 30-Day Rolling Beta")
